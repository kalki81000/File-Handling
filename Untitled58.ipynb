# %% [markdown]
# <a href="https://colab.research.google.com/github/kalki81000/File-Handling/blob/main/Untitled58.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification

# %%
x , y =make_classification(n_samples = 1000, n_features=10 , n_classes = 2 , random_state =1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test,y_train, y_test = train_test_split(x,y, test_size = 0.20 ,random_state=1)

# %%
rf = RandomForestClassifier()

# %%
rf
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV
params = {'max_depth' :[1,2,3,5,10,None],
          'n_estimators' : [50,100,200,300],
          'criterion':['gini','entropy']}

# %%
params
# Out:
# {'max_depth': [1, 2, 3, 5, 10, None],
#  'n_estimators': [50, 100, 200, 300],
#  'criterion': ['gini', 'entropy']}

# %%
clf = RandomizedSearchCV(rf , param_distributions=params , cv = 5 , verbose = 3 , scoring = 'accuracy')

# %%
clf
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 5, 10, None],
#                                         'n_estimators': [50, 100, 200, 300]},
#                    scoring='accuracy', verbose=3)

# %%
clf.fit(x_train , y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.894 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.819 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.850 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.863 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.831 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.912 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.825 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.844 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.863 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.831 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.906 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.825 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.856 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.856 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=50;, score=0.831 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.812 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.856 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.863 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.831 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, n_estimators=200;, score=0.912 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, n_estimators=200;, score=0.825 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, n_estimators=200;, score=0.856 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, n_estimators=200;, score=0.856 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, n_estimators=200;, score=0.831 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=1, n_estimators=200;, score=0.906 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=1, n_estimators=200;, score=0.819 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=1, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=1, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=1, n_estimators=200;, score=0.831 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.906 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.794 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.863 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.838 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.919 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.856 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.863 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.856 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.838 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=50;, score=0.912 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=50;, score=0.844 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=50;, score=0.844 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=50;, score=0.869 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=50;, score=0.838 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.912 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.825 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.856 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.863 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.831 total time=   0.7s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 5, 10, None],
#                                         'n_estimators': [50, 100, 200, 300]},
#                    scoring='accuracy', verbose=3)

# %%
clf.best_params_
# Out:
# {'n_estimators': 300, 'max_depth': 10, 'criterion': 'gini'}

# %%
clf.best_score_
# Out:
# 0.8662500000000002

# %%
#internal homeworks
#use total_bill as target variable and make it a regressor problem
#automate fe, training . testing, and also , random forest regressor with mlr , svr models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")


df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
x =df.drop('total_bill',axis =1)
y=df['total_bill']

# %%
x
# Out:
#       tip     sex smoker   day    time  size
# 0    1.01  Female     No   Sun  Dinner     2
# 1    1.66    Male     No   Sun  Dinner     3
# 2    3.50    Male     No   Sun  Dinner     3
# 3    3.31    Male     No   Sun  Dinner     2
# 4    3.61  Female     No   Sun  Dinner     4
# ..    ...     ...    ...   ...     ...   ...
# 239  5.92    Male     No   Sat  Dinner     3
# 240  2.00  Female    Yes   Sat  Dinner     2
# 241  2.00    Male    Yes   Sat  Dinner     2
# 242  1.75    Male     No   Sat  Dinner     2
# 243  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size = 0.20 , random_state=1)

# %%
#Handling the missing value
#data encoding
#feature scaling

from sklearn.impute import SimpleImputer # For missing value
from sklearn.preprocessing import OneHotEncoder #for encoding
from sklearn.preprocessing import StandardScaler # for scaling

# %%
from sklearn.pipeline import Pipeline # a sequence of data transformer
from sklearn.compose import ColumnTransformer

# %%
cat_cols = ['sex' , 'smoker', 'day','time']
num_cols = [ 'tips', 'size']

# %%
#feature engenerring automative using pipeline and columntransfer

num_pipeline = Pipeline(steps = [('imputation' , SimpleImputer(strategy = 'median')) ,('scaling' , StandardScaler())])
cat_pipeline = Pipeline(steps = [('imputation' , SimpleImputer(strategy = 'most_frequent')) ,('encoding' , OneHotEncoder())])

# %%
preprocessor = ColumnTransformer([("num_pipeline" , num_pipeline , num_cols) , "cat_pipeline" , cat_pipeline , cat_cols])


x_train = preprocessor.fit_transform(x_train)
x_test = preprocessor.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-0b2c97524320> in <cell line: 4>()
#       2
#       3
# ----> 4 x_train = preprocessor.fit_transform(x_train)
#       5 x_test = preprocessor.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     748         # set n_features_in_ attribute
#     749         self._check_n_features(X, reset=True)
# --> 750         self._validate_transformers()
#     751         self._validate_column_callables(X)
#     752         self._validate_remainder(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in _validate_transformers(self)
#     428             return
#     429
# --> 430         names, transformers, _ = zip(*self.transformers)
#     431
#     432         # validate names
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
